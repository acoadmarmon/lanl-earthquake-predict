# %%
import pickle

with open('../../data/15000_processed_data/train_labels.pkl', 'rb') as f:
    train_labels = pickle.load(f)
    
with open('../../data/15000_processed_data/eval_labels.pkl', 'rb') as f:
    eval_labels = pickle.load(f)

# %%
import seaborn as sns
sns.distplot(list(train_labels.values()))

# %%
sns.distplot(list(eval_labels.values()))

# %%
with open('../../data/15000_processed_data/train_labels.pkl', 'wb') as f:
    pickle.dump(train_labels, f, protocol=2)
    
with open('../../data/15000_processed_data/eval_labels.pkl', 'wb') as f:
    pickle.dump(eval_labels, f, protocol=2)
